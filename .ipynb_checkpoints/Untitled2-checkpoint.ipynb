# %%
import pandas as pd

# %%
oo = pd.read_csv("olympics.csv", skiprows=4)

# %%
nflx = pd.read_csv("nflx_trades.csv")

# %%
nflx
# Out:
#                 id symbol             ts   price  size          dt
# 0        657469545   NFLX  1490908043387  148.16  10.0  2017-03-30
# 1        657469544   NFLX  1490908033876  148.09   2.0  2017-03-30
# 2        657469543   NFLX  1490907945582  147.96   1.0  2017-03-30
# 3        657469542   NFLX  1490907940077  147.97   2.0  2017-03-30
# 4        657469541   NFLX  1490907927563  148.00  14.0  2017-03-30
# 5        657469540   NFLX  1490907816459  148.00   2.0  2017-03-30
# 6        657469539   NFLX  1490907815207  148.00   1.0  2017-03-30
# 7        657469538   NFLX  1490907606497  148.08   2.0  2017-03-30
# 8        657469537   NFLX  1490907327151  148.05   4.0  2017-03-30
# 9        657469536   NFLX  1490906192972  148.10   1.0  2017-03-30
# 10       657469535   NFLX  1490906189718  148.06   1.0  2017-03-30
# 11       657469534   NFLX  1490906187965  148.10   1.0  2017-03-30
# 12       657469533   NFLX  1490905337448  148.10   1.0  2017-03-30
# ...

# %%
type(oo[["City","Edition","NOC","Athlete"]])

# %%
type(oo.NOC)

# %%
oo.head()

# %%
oo.shape

# %%
oo.shape[0]

# %%
oo.info()

# %%
oo[("Edition" >= 1984), ("Edition" <= 2008)]

# %%
oo.Gender.value_counts(ascending=True, dropna=False)

# %%
ath = oo.Athlete.sort_values()

# %%
oo.sort_values(by=["Edition","Athlete"])

# %%
oo[(oo.Medal == "Gold") & (oo.Gender == "Women") ]

# %%
oo[oo.Athlete.str.contains("Florence")]

# %%
oo[oo.Athlete.str.contains("OWENS")]

# %%
oo.value_counts(oo)

# %%
ov = oo.Medal.value_counts()

# %%
ov.sort_counts()

# %%
ov = oo[(oo.Medal == "Gold") & (oo.Discipline.str.contains("Badminton")) & (oo.Event == "doubles") ]

# %%
type(ov)

# %%
oo.Edition
# Out:
# 0        1896
# 1        1896
# 2        1896
# 3        1896
# 4        1896
# 5        1896
# 6        1896
# 7        1896
# 8        1896
# 9        1896
# 10       1896
# 11       1896
# 12       1896
# 13       1896
# 14       1896
# 15       1896
# 16       1896
# 17       1896
# 18       1896
# 19       1896
# 20       1896
# 21       1896
# 22       1896
# 23       1896
# 24       1896
# 25       1896
# 26       1896
# 27       1896
# 28       1896
# 29       1896
#          ...
# 29186    2008
# 29187    2008
# 29188    2008
# 29189    2008
# 29190    2008
# 29191    2008
# 29192    2008
# 29193    2008
# 29194    2008
# 29195    2008
# 29196    2008
# 29197    2008
# 29198    2008
# 29199    2008
# 29200    2008
# 29201    2008
# 29202    2008
# 29203    2008
# 29204    2008
# 29205    2008
# 29206    2008
# 29207    2008
# 29208    2008
# 29209    2008
# 29210    2008
# 29211    2008
# 29212    2008
# 29213    2008
# 29214    2008
# 29215    2008
# ...

# %%
ol = oo[oo.Edition >= 1984]

# %%
type(ol)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Most Medals between 1984 and 2008

# %%
ov = ol.NOC.value_counts()

# %%
type (ov)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Display the male gold medal winner for the 100m track and field sprint event over the years

# %%
jo = oo[oo.Athlete == "OWENS, Jesse"]

# %%
jo.Event.value_counts()
# Out:
# 4x100m relay    1
# long jump       1
# 200m            1
# 100m            1
# Name: Event, dtype: int64

# %%
gbm = oo[(oo.Medal == "Gold") & (oo.Gender == "Men") & (oo.Sport == "Badminton")]

# %%
gbm.sort_values(by = "Athlete")
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
recent = oo[(oo.Edition >= 1984)]

# %%
recent.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
gmh = oo[(oo.Event == "100m") & (oo.Gender == "Men") & (oo.Medal == "Gold")]

# %%
gmhr = gmh.sort_values("Edition", ascending=False)

# %%
gmhr[["City","Edition","Athlete","NOC"]]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
lo = oo[oo.Edition == 2008]

# %%
lo
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 27174  Beijing     2008   Aquatics           Diving         GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving       MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving            ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving              WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving           CHEN, Ruolin
# 27179  Beijing     2008   Aquatics           Diving        HEYMANS, Emilie
# 27180  Beijing     2008   Aquatics           Diving               QIN, Kai
# 27181  Beijing     2008   Aquatics           Diving              HE, Chong
# 27182  Beijing     2008   Aquatics           Diving    DESPATIE, Alexandre
# 27183  Beijing     2008   Aquatics           Diving             WU, Minxia
# 27184  Beijing     2008   Aquatics           Diving          GUO, Jingjing
# ...

# %%
noc = pd.read_csv("noc.csv")

# %%
noc[noc.Country != noc["Country.1"]]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc.set_index("Int Olympic Committee code", inplace=True)

# %%
medal_2008 = lo.NOC.value_counts()

# %%
noc['medal_2008'] = medal_2008

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN
